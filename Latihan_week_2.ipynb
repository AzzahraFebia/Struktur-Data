# %% [markdown]
# <a href="https://colab.research.google.com/github/AzzahraFebia/Struktur-Data/blob/main/Latihan_week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Singly Linked List
class singlyLinkedList:
  def _init_(self):
    self.head = None

  def insert_at_end(self, data):
    new_node = Node (data)
    if not self.head:
      self .head = new_node
      return
    temp = self.head
    while temp.next:
      temp = temp.next
    temp.next = new_node

  def display(self):
    temp = self.head
    while temp:
      print(temp.data, end='->')
      temp = temp.next
    print('None')

# %%
# Doubly Linked List
class DoublyNode:
  def _init_(self, data):
    self.data = data
    self.prev = None
    self.next = None

class DoublyLinkedList:
  def _init_(self):
    self.head = None

  def insert_at_end(self, data):
    new_node = DoublyNode(data)
    if not self.head:
      self.head = new_node
      return
    temp = self.head
    while temp.next:
      temp = temp.next
    temp.next = new_node
    new_node.prev = temp

  def display(self):
    temp = self.head
    while temp:
      print(temp.data, end='->')
      temp = temp.next
    print('None')

# %%
# Circular Linked List
class CircularLinkedList:
  def _init_(self):
    self.head = None

  def insert_at_end(self, data):
    new_node = Node(data)
    if not self.head:
      self.head = new_node
      new_node.next = self.head
      return
    temp = self.head
    while temp.next != self.head:
      temp = temp.next
    temp.next = new_node
    new_node.next = self.head

  def display(self):
    if not self.head:
      return
    temp = self.head
    while True:
      print(temp.data, end='->')
      temp = temp.next
      if temp == self.head:
        break
    print('(Back to Head)')

# %% [markdown]
# IMPLEMENTASI SINGLY LINKED LIST

# %%
# Definisi Node dalam Linked List
class TaskNode:
    def __init__(self, task_name):
       self.task_name = task_name
       self.next = None

# Definisi Linked List untuk Daftar Tugas
class TaskList:
    def __init__(self):
        self.head = None

    # Menambahkan tugas ke Linked List
    def add_task(self, task_name):
        new_task = TaskNode(task_name)
        if not self.head:
            self.head = new_task
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_task

    # Menampilkan daftar tugas
    def show_tasks(self):
        if not self.head:
            print("\nTidah ada tugas hari ini!")
            return
        print("\nDaftar Tugas Hari Ini:")
        current = self.head
        count = 1
        while current:
            print(f"{count}. {current.task_name}")
            current = current.next
            count += 1

# ===== Program Utama (Main) ===== #

# Membuat objek daftar tugas
task_list = TaskList()

# Meminta pengguna memasukkan jumlah tugas
num_tasks = int(input("Masukkan jumlah tugas hari ini: "))

# Meminta pengguna memasukkan tugas ke dalam Linked List
for i in range(1, num_tasks + 1):
    task_name = input(f"Masukkan tugas ke-{i}: ")
    task_list.add_task(task_name)

# Menampilkan hasil daftar tugas
task_list.show_tasks()
# Out:
# Masukkan jumlah tugas hari ini: 3
# Masukkan tugas ke-1: kalkulus
# Masukkan tugas ke-2: fisika
# Masukkan tugas ke-3: kimia
#
# Daftar Tugas Hari Ini:
# 1. kalkulus
# 2. fisika
# 3. kimia

# %% [markdown]
# IMPLEMENTASI DOUBLY LINKED LIST

# %%
# Definisi Node dalam Doubly Linked List
class PageNode:
  def __init__(self, url):
    self.url = url # URL halaman web
    self.prev = None # Pointer ke halaman berikutnya
    self.next = None # Pointer ke halaman sebelumnya

# Definisi Doubly Linked List untuk Riwayat Peramban
class BrowserHistory:
  def __init__(self):
    self.current = None # Pointer ke halaman yang sedang dibuka

  # Menambahkan halaman baru ke dalam riwayat
  def visit_page(self, url):
    new_page = PageNode(url)
    if not self.current:
      self.current = new_page # Jika riwayat kosong, halaman ini menjadi halaman pertama
    else:
      new_page.prev = self.current
      self.current.next = new_page
      self.current = new_page # Pindahkan posisi ke halaman baru

  # Menampilkan riwayat kunjungan
  def show_history(self):
   if not self.current:
      print("\nRiwayat kosong.")
      return

   print("\nRiwayat Peramban Web:")
   temp = self.current
   while temp.prev: # Kembali ke halaman pertama
      temp = temp.prev

   count = 1
   while temp:
      print(f"{count}. {temp.url}")
      temp = temp.next
      count += 1

 # Navigasi mundur ke halaman sebelumnya
  def go_back(self):
   if self.current and self.current.prev:
    self.current = self.current.prev
    print(f"\nAnda kembali ke: {self.current.url}!")
   else:
     print("\nTidak bisa kembali, ini adalah halaman pertama.")

 # Navigasi maju ke halaman berikutnya
  def go_forward(self):
   if self.current and self.current.next:
    self.current = self.current.next
    print(f"\nBerhasil maju ke: {self.current.url}")
   else:
    print("\nTidak bisa maju, ini adalah halaman terakhir!")

# ===== Program Utama (Main) ===== #

# Membuat objek riwayat navigasi halaman
history = BrowserHistory()

# Meminta pengguna memasukkan jumlah halaman yang dikunjungi
num_pages = int(input("\nMasukkan jumlah halaman yang dikunjungi: "))

# Loop untuk memasukkan URL halaman ke dalam Doubly Linked List
for i in range(1, num_pages + 1):
  url = input(f"Masukkan url halaman ke-{i}: ")
  history.visit_page(url)

# Menampilkan riwayat yang telah dimasukkan
history.show_history()

# Menu navigasi pengguna
while True:
  command = input("\nTekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.\nMasukkan perintah: ").lower()
  if command == 'b':
    history.go_back()
  elif command == 'f':
    history.go_forward()
  elif command == 'x':
    print("\nKeluar dari riwayat peramban.")
    break
  else:
    print("\nPerintah tidak dikenal.")
# Out:
# Masukkan jumlah halaman yang dikunjungi: 2
# Masukkan url halaman ke-1: oreii
# Masukkan url halaman ke-2: nnou
#
# Riwayat Peramban Web:
# 1. oreii
# 2. nnou
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: b
#
# Anda kembali ke: oreii!
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: b
#
# Tidak bisa kembali, ini adalah halaman pertama.
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: f
#
# Berhasil maju ke: nnou
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: f
#
# Tidak bisa maju, ini adalah halaman terakhir!
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: x
#
# Keluar dari riwayat peramban.

# %% [markdown]
# IMPLEMENTASI CIRCULAR LINKED LIST

# %%
# Definisi Node dalam Circular Linked List
class SongNode:
  def __init__(self, title): # Corrected the constructor name to __init__
    self.title = title
    self.next = None

# Definisi Circular Linked List untuk Playlist Lagu
class Playlist:
  def __init__(self):
    self.current = None

  # Menambahkan lagu ke dalam playlist
  def add_song(self, title):
    new_song = SongNode(title)
    if not self.current:
      self.current = new_song
      self.current.next = self.current
    else:
      temp = self.current
      while temp.next != self.current:
        temp = temp.next
      temp.next = new_song
      new_song.next = self.current

  # Menampilkan daftar lagu dalam playlist
  def show_playlist(self):
    if not self.current:
      print('\nPlaylist kosong!')
      return

    print('\nPlaylist Lagu Anda: ')
    temp = self.current
    count = 1
    while True:
      print(f'{count}. {temp.title}')
      temp = temp.next
      count += 1
      if temp == self.current:
        break

  # Memutar lagu berikutnya dalam playlist
  def next_song(self):
    if self.current:
      self.current = self.current.next
      print(f'\n Memutar: {self.current.title}')

# ====== Program Utama (Main) ====== #

# Membuat objek playlist
playlist = Playlist()

# Meminta pengguna memasukkan jumlah lagu
num_songs = int(input('\nMasukkan jumlah lagu dalam playlist: '))

# Loop untuk memasukkan lagu ke dalam Circular Linked List
for i in range(1, num_songs + 1):
  title = input(f'Masukkan judul lagu ke-{i}: ')
  playlist.add_song(title)

# Menampilkan daftar lagu
playlist.show_playlist()

#Menu navigasi pengguna
while True:
  command = input('\nTekan "n" untuk lagu berikutnya, Tekan "x" untuk keluar. \nMasukkan perintah: ').lower()
  if command == 'n':
    playlist.next_song()
  elif command == 'x':
    print('\nKeluar dari pemutar musik.')
    break
  else:
    print('\nPerintah tidak dikenal.')
# Out:
# Masukkan jumlah lagu dalam playlist: 2
# Masukkan judul lagu ke-1: WAVE
# Masukkan judul lagu ke-2: Empty Box
#
# Playlist Lagu Anda:
# 1. WAVE
# 2. Empty Box
#
# Tekan "n" untuk lagu berikutnya, Tekan "x" untuk keluar.
# Masukkan perintah: n
#
#  Memutar: Empty Box
#
# Tekan "n" untuk lagu berikutnya, Tekan "x" untuk keluar.
# Masukkan perintah: x
#
# Keluar dari pemutar musik.

# %% [markdown]
# LATIHAN

# %% [markdown]
# Latihan 1
#
# Buatlah program yang menampilkan jadwal mata kuliah di hari Jum'at dengan jumlah mata kuliah sesuai digit terakhir NPM!

# %%
# Definisi Node dalam Linked List
class TaskNode:
    def __init__(self, task_name):
       self.task_name = task_name
       self.next = None

# Definisi Linked List untuk Daftar Tugas
class TaskList:
    def __init__(self):
        self.head = None

    # Menambahkan tugas ke Linked List
    def add_task(self, task_name):
        new_task = TaskNode(task_name)
        if not self.head:
            self.head = new_task
        else:
            current = self.head
            while current.next:
                current = current.next
            current.next = new_task

    # Menampilkan daftar tugas
    def show_tasks(self):
        if not self.head:
            print("\nJadwal kosong")
            return
        print("\nJadwal Hari Jum'at:")
        current = self.head
        count = 1
        while current:
            print(f"{count}. {current.task_name}")
            current = current.next
            count += 1

# ===== Program Utama (Main) ===== #

# Membuat objek daftar tugas
task_list = TaskList()

# Meminta pengguna memasukkan jumlah tugas
num_tasks = int(input("Jumlah jadwal hari Jum'at: "))

# Meminta pengguna memasukkan nama-nama tugas
for i in range(1, num_tasks + 1):
    task_name = input(f"Masukkan jadwal ke-{i}: ")
    task_list.add_task(task_name)

# Menampilkan hasil daftar tugas
task_list.show_tasks()
# Out:
# Jumlah jadwal hari Jum'at: 3
# Masukkan jadwal ke-1: Biologi
# Masukkan jadwal ke-2: Kalkulus
# Masukkan jadwal ke-3: Bahasa Indonesia
#
# Jadwal Hari Jum'at:
# 1. Biologi
# 2. Kalkulus
# 3. Bahasa Indonesia

# %% [markdown]
# Latihan 2
#
# Buatlah program yang menampilkan riwayat navigasi folder dalam File Explorer menggunakan Doubly Linked List. Jumlah folder yang di navigasikan sesuai dengan digit terakhir NPM!

# %%
# Definisi Node dalam Doubly Linked List
class FolderNode:
  def __init__(self, nama_folder):
    self.nama_folder = nama_folder # URL halaman web
    self.prev = None # Pointer ke halaman berikutnya
    self.next = None # Pointer ke halaman sebelumnya

# Definisi Doubly Linked List untuk Riwayat Navigasi Folder
class FolderHistory:
  def __init__(self):
    self.current = None # Pointer ke halaman yang sedang dibuka

  # Menambahkan folder baru ke dalam riwayat
  def visit_folder(self, nama_folder):
    new_folder = FolderNode(nama_folder)
    if not self.current:
      self.current = new_folder # Jika riwayat kosong, folder ini menjadi folder pertama
    else:
      new_folder.prev = self.current
      self.current.next = new_folder
      self.current = new_folder # Pindahkan posisi ke folder baru

  # Menampilkan riwayat kunjungan folder
  def show_history(self):
   if not self.current:
      print("\nRiwayat kosong.")
      return

   print("\nRiwayat Navigasi Folder:")
   temp = self.current
   while temp.prev: # Kembali ke folder pertama
      temp = temp.prev

   count = 1
   while temp:
      print(f"{count}. {temp.nama_folder}")
      temp = temp.next
      count += 1

 # Navigasi mundur ke folder sebelumnya
  def go_back(self):
   if self.current and self.current.prev:
    self.current = self.current.prev
    print(f"\nAnda kembali, ini adalah folder {self.current.nama_folder}!")
   else:
     print("\nTidak bisa kembali, ini adalah folder pertama.")

 # Navigasi maju ke folder berikutnya
  def go_forward(self):
   if self.current and self.current.next:
    self.current = self.current.next
    print(f"\nBerhasil maju, ini adalah folder {self.current.nama_folder}")
   else:
    print("\nTidak bisa maju, ini adalah folder terakhir!")

# ===== Program Utama (Main) ===== #
print("----- Navigasi Folder -----")
# Membuat objek riwayat navigasi folder
history = FolderHistory()

# Meminta pengguna memasukkan jumlah folder yang dikunjungi
num_folders = int(input("\nMasukkan jumlah folder yang dikunjungi: "))

# Loop untuk memasukkan folder ke dalam Doubly Linked List
for i in range(1, num_folders + 1):
  nama_folder = input(f"Masukkan nama folder ke-{i}: ")
  history.visit_folder(nama_folder)

# Menampilkan riwayat yang telah dimasukkan
history.show_history()

# Menu navigasi pengguna
while True:
  command = input("\nTekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.\nMasukkan perintah: ").lower()
  if command == 'b':
    history.go_back()
  elif command == 'f':
    history.go_forward()
  elif command == 'x':
    print("\nKeluar dari riwayat navigasi folder.")
    break
  else:
    print("\nPerintah tidak dikenal.")
# Out:
# ----- Navigasi Folder -----
#
# Masukkan jumlah folder yang dikunjungi: 3
# Masukkan nama folder ke-1: Box
# Masukkan nama folder ke-2: Crazy
# Masukkan nama folder ke-3: Fever
#
# Riwayat Navigasi Folder:
# 1. Box
# 2. Crazy
# 3. Fever
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: b
#
# Anda kembali, ini adalah folder Crazy!
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: b
#
# Anda kembali, ini adalah folder Box!
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: b
#
# Tidak bisa kembali, ini adalah folder pertama.
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: f
#
# Berhasil maju, ini adalah folder Crazy
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: f
#
# Berhasil maju, ini adalah folder Fever
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: f
#
# Tidak bisa maju, ini adalah folder terakhir!
#
# Tekan 'b' untuk kembali, tekan 'f' untuk maju, tekan 'x' untuk keluar.
# Masukkan perintah: x
#
# Keluar dari riwayat navigasi folder.

# %% [markdown]
# Latihan 3
#
# Dalam laporan, tuliskan penjelasan mengenai bagaimana implementasi operasi-operasi dasar pada Linked List dalam kode program di bawah diterapkan!

# %%
# Definisi Node dalam Singly Linked List
class Node:
  def __init__(self, data):
    self.data = data # Menyimpan nilai node
    self.next = None # Pointer ke node berikutnya

# Definisi Singly Linked List dengan Berbagai Operasi
class LinkedList:
  def __init__(self):
    self.head = None # Awalnya, daftar kosong

  # Menambahkan elemen di awal
  def add_at_beginning(self, data):
    new_node = Node(data)
    new_node.next = self.head
    self.head = new_node

  # Menambahkan elemen di akhir
  def add_at_end(self, data):
    new_node = Node(data)
    if not self.head:
      self.head = new_node
      return
    temp = self.head
    while temp.next:
      temp = temp.next
      temp.next = new_node

  # Menambahkan elemen di posisi tertentu
  def add_at_position(self, position, data):
    if position < 0:
      print("Posisi tidak valid!")
      return
    new_node = Node(data)
    if position == 0:
      self.add_at_beginning(data)
      return
    temp = self.head
    for _ in range(position - 1):
      if not temp:
        print("Posisi melebihi panjang daftar!")
        return
      temp = temp.next
    temp.next = new_node

  # Menghapus elemen di awal
  def delete_at_beginning(self):
    if not self.head:
      print("Daftar kosong, tidak ada yang bisa dihapus!")
      return
    self.head = self.head.next

  # Menghapus elemen di akhir
  def delete_at_end(self):
    if not self.head:
      print("Daftar kosong, tidak ada yang bisa dihapus!")
      return
    if not self.head.next:
      self.head = None
      return
    temp = self.head
    while temp.next.next:
      temp = temp.next
    temp.next = None

  # Menghapus elemen di posisi tertentu
  def delete_at_position(self, position):
    if not self.head:
      print(" Daftar kosong, tidak ada yang bisa dihapus!")
      return
    if position == 0:
      self.head == self.head.next
      return
    temp = self.head
    for _ in range(position -1):
      if not temp or not temp.next:
        print("Posisi ini tidak ditemukan!")
        return
      temp = temp.next
    temp.next = temp.next.next

  # Mencari elemen dalam Linked List
  def search(self, key):
    temp = self.head
    while temp:
      if temp.data == key:
        print(f" Elemen {key} ditemukan dalam daftar!")
        return
      temp = temp.next
    print(f" Elemen {key} tidak ditemukan dalam daftar!")

  # Membalik (reverse) Linked List
  def reverse(self):
    prev = None
    current = self.head
    while current:
      next_node = current.next
      current.next = prev
      prev = current
      current = next_node
    self.head = prev

  # Menampilkan Linked List
  def display(self):
    if not self.head:
      print("Daftar kosong!")
      return
    temp = self.head
    while temp:
      print(temp.data, end=" -> ")
      temp = temp.next
    print("None")

# ===== Program Utama (Main) ===== #
# Membuart objek Linked List
ll = LinkedList()

# Meminta pengguna memasukkan elemen awal
num_elements = int(input("\nMasukkan jumlah awal elemen dalam daftar: "))
for i in range(num_elements):
  data = int(input(f"Masukkan data ke-{i+1}: "))
  ll.add_at_end(data)

# Menu Operasi Linked List
while True:
  print("\n Pilih Operasi:")
  print("1. Tambah elemen di awal")
  print("2. Tambah elemen di akhir")
  print("3. Tambah elemen di posisi tertentu")
  print("4. Hapus elemen di awal")
  print("5. Hapus elemen di akhir")
  print("6. Hapus elemen di posisi tertentu")
  print("7. Cari elemen dalam daftar")
  print("8. Balikkan daftar")
  print("9. Tampilkan daftar")
  print("0. Keluar")

  choice = int(input("\nMasukkan pilihan: "))

  if choice == 1 :
    data = int(input("Masukkan data yang ingin ditambahkan di awal: "))
  elif choice == 2 :
    data = int(input("Masukkan data yang ingin ditambahkan di akhir: "))
  elif choice == 3 :
    position = int(input("Masukkan posisi untuk menambahkan data: "))
    data = int(input("Masukkan data yang ingin ditambahkan: "))
    ll.add_at_position(position, data)
  elif choice == 4 :
    ll.delete_at_beginning()
  elif choice == 5 :
    ll.delete_at_end()
  elif choice == 6 :
    position = int(input("Masukkan posisi elemen yang ingin dihapus: "))
    ll.delete_at_position(position)
  elif choice == 7 :
    key = int(input("Masukkan elemen yang ingin dicari: "))
    ll.search(key)
  elif choice == 8 :
    ll.reverse()
    print(" Daftar berhasil dibalik!")
  elif choice == 9 :
    ll.display()
  elif choice == 0 :
    print("\n Keluar dari porgram.")
    break
  else:
    print("\n Pilihan tidak valid, silakan coba lagi!")
# Out:
# Masukkan jumlah awal elemen dalam daftar: 2
# Masukkan data ke-1: 1
# Masukkan data ke-2: 2
#
#  Pilih Operasi:
# 1. Tambah elemen di awal
# 2. Tambah elemen di akhir
# 3. Tambah elemen di posisi tertentu
# 4. Hapus elemen di awal
# 5. Hapus elemen di akhir
# 6. Hapus elemen di posisi tertentu
# 7. Cari elemen dalam daftar
# 8. Balikkan daftar
# 9. Tampilkan daftar
# 0. Keluar
#
# Masukkan pilihan: 0
#
#  Keluar dari porgram.
